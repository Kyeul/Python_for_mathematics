# %% [markdown]
# p.44
# 1-5 다음 문제를 계산하시오. 단, 근호 안의 숫자가 최소가 되도록 표현하시오.
#
# 1. $4^4 \times 2^{-1} \div 2^2$
# 2. $ \sqrt[3]{81} \times \sqrt[3]{9}$
# 3. $ \sqrt[3]{\sqrt{64}} $

# %%
import math

# %%
#1
(4**4)*(2**(-1))/(2**2)
# Out:
# 32.0

# %%
#2
math.ceil((81**(1/3))*(9**(1/3)))
# Out:
# 9

# %%
#3
((64**(1/2))**(1/3))
# Out:
# 2.0
